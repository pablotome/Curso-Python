# %% [markdown]
# Instalo PyDrive
# !pip install PyDrive

# %%
# !pip install PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1tv-8gVk15Od9aSdEZicWhbFf9d4veYa2"})   # replace the id with id of file you want to access
downloaded.GetContentFile('Sample-Spreadsheet-5000-rows.csv')        # replace the file name with your file

# %%
import pandas as pd
data = pd.read_csv('Sample-Spreadsheet-5000-rows.csv', encoding='unicode_escape')

# %%
data.head(2)
# Out:
#    ID  ... Porcentaje
# 0   1  ...       0.80
# 1   2  ...       0.58
#
# [2 rows x 10 columns]

# %%
data.tail(3)
# Out:
#         ID  ... Porcentaje
# 4997  4998  ...       0.52
# 4998  4999  ...       0.36
# 4999  5000  ...       0.35
#
# [3 rows x 10 columns]

# %%
data.dtypes
# Out:
# ID               int64
# Titulo          object
# Nombre          object
# Cantidad         int64
# Saldo          float64
# UltimaVenta    float64
# Saldo2         float64
# Clase           object
# Categoria       object
# Porcentaje     float64
# dtype: object

# %%
data.to_excel("ejemplo_excel.xls", sheet_name="datos", index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5000 non-null   int64
#  1   Titulo       5000 non-null   object
#  2   Nombre       5000 non-null   object
#  3   Cantidad     5000 non-null   int64
#  4   Saldo        5000 non-null   float64
#  5   UltimaVenta  5000 non-null   float64
#  6   Saldo2       5000 non-null   float64
#  7   Clase        5000 non-null   object
#  8   Categoria    5000 non-null   object
#  9   Porcentaje   4964 non-null   float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 390.8+ KB

# %%
titulos = data["Titulo"]

# %%
titulos
# Out:
# 0        Eldon Base for stackable storage shelf, platinum
# 1       1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2         Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# 3                                                    R380
# 4                                Holmes HEPA Air Purifier
#                               ...
# 4995                   Sanford Liquid Accent Highlighters
# 4996               Global Stack Chair without Arms, Black
# 4997                                   Canon PC940 Copier
# 4998    Rediform Wirebound "Phone Memo" Message Book, ...
# 4999                         Vinyl Sectional Post Binders
# Name: Titulo, Length: 5000, dtype: object

# %%
saldos = data["Saldo"]

# %%
saldos
# Out:
# 0       -213.25
# 1        457.81
# 2         46.71
# 3       1198.97
# 4         30.94
#          ...
# 4995      55.21
# 4996     -70.43
# 4997    3825.69
# 4998     -22.36
# 4999     317.53
# Name: Saldo, Length: 5000, dtype: float64

# %%
type(saldos)
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (5000, 10)

# %%
data["Saldo"].shape
# Out:
# (5000,)

# %%
data[["Titulo", "Saldo"]]
# Out:
#                                                  Titulo    Saldo
# 0      Eldon Base for stackable storage shelf, platinum  -213.25
# 1     1.7 Cubic Foot Compact "Cube" Office Refrigera...   457.81
# 2       Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    46.71
# 3                                                  R380  1198.97
# 4                              Holmes HEPA Air Purifier    30.94
# ...                                                 ...      ...
# 4995                 Sanford Liquid Accent Highlighters    55.21
# 4996             Global Stack Chair without Arms, Black   -70.43
# 4997                                 Canon PC940 Copier  3825.69
# 4998  Rediform Wirebound "Phone Memo" Message Book, ...   -22.36
# 4999                       Vinyl Sectional Post Binders   317.53
#
# [5000 rows x 2 columns]

# %%
data[["Titulo", "Saldo"]].shape
# Out:
# (5000, 2)

# %%
data[(data['Saldo'] > 400) & (data['Saldo'] < 1000)]
# Out:
#         ID  ... Porcentaje
# 1        2  ...       0.58
# 15      16  ...       0.53
# 17      18  ...       0.60
# 50      51  ...       0.42
# 68      69  ...       0.54
# ...    ...  ...        ...
# 4911  4912  ...       0.37
# 4952  4953  ...       0.35
# 4971  4972  ...       0.46
# 4985  4986  ...       0.55
# 4989  4990  ...       0.59
#
# [412 rows x 10 columns]

# %%
data.loc[(data['Saldo'] > 400) & (data['Saldo'] < 1000), "Nombre"]
# Out:
# 1          Barry French
# 15      Neola Schneider
# 17      Sylvia Foulston
# 50        Clay Rozendal
# 68       Dorothy Wardle
#              ...
# 4911     Jill Stevenson
# 4952       Tom Zandusky
# 4971     Natalie Webber
# 4985         Ryan Crowe
# 4989    Penelope Sewall
# Name: Nombre, Length: 412, dtype: object

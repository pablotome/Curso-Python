# %%
import numpy as np
dias = np.arange('2021-01-01', 10, dtype='datetime64[D]')
print(dias)
# Out:
# ['2021-01-01' '2021-01-02' '2021-01-03' '2021-01-04' '2021-01-05'
#  '2021-01-06' '2021-01-07' '2021-01-08' '2021-01-09' '2021-01-10']

# %%
import pandas as pd
d = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/agencia-de-proteccion-ambiental/calidad-aire/calidad-aire.csv")

# %%
d.dtypes
# Out:
# FECHA               object
# HORA                 int64
# CO_CENTENARIO       object
# NO2_CENTENARIO      object
# PM10_CENTENARIO     object
# CO_CORDOBA          object
# NO2_CORDOBA         object
# PM10_CORDOBA        object
# CO_LA_BOCA          object
# NO2_LA_BOCA         object
# PM10_LA_BOCA        object
# CO_PALERMO          object
# NO2_PALERMO        float64
# PM10_PALERMO       float64
# dtype: object

# %%
fecha_hora = d['FECHA'] + ' ' + str(d['HORA'])
#d.index = pd.to_datetime(fecha_hora)
#print(fecha_hora)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(10000)
plt.hist(x, 100)
plt.title('titulo')
plt.xlabel('X')
plt.show()

# %%
ventas = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/acceso-vivienda-y-mercado-inmobiliario/precio-alquiler-deptos.csv")
ventas
# Out:
#              barrio  anio  mes  precio_prom    ambientes  comuna
# 0         AGRONOMIA  2013  Jul          NaN  3 ambientes      15
# 1         AGRONOMIA  2013  Ago          NaN  3 ambientes      15
# 2         AGRONOMIA  2013  Sep          NaN  3 ambientes      15
# 3         AGRONOMIA  2013  Oct          NaN  3 ambientes      15
# 4         AGRONOMIA  2013  Nov          NaN  3 ambientes      15
# ...             ...   ...  ...          ...          ...     ...
# 7099  VILLA URQUIZA  2019  Abr      14638.0  2 ambientes      12
# 7100  VILLA URQUIZA  2019  May      14544.0  2 ambientes      12
# 7101  VILLA URQUIZA  2019  Jun      15371.0  2 ambientes      12
# 7102  VILLA URQUIZA  2019  Jul      15132.0  2 ambientes      12
# 7103  VILLA URQUIZA  2019  Ago          NaN  2 ambientes      12
#
# [7104 rows x 6 columns]

# %%
import pandas as pd
d2 = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/instituto-de-vivienda/mercado-inmobiliario/actas-notariales-compra-venta-inmuebles-hipotecas.csv")
d2
# Out:
#      año_mes  \
# 0    2002-01
# 1    2002-02
# 2    2002-03
# 3    2002-04
# 4    2002-05
# ..       ...
# 225  2020-10
# 226  2020-11
# 227  2020-12
# 228  2021-01
# 229  2021-02
#
#      Actos notariales de compra venta de inmuebles anotados en el Colegio de Escribanos. CABA   \
# 0                                                 1678
# 1                                                 1557
# 2                                                 3434
# 3                                                 8035
# 4                                                 8098
# ..                                                 ...
# 225                                               2528
# 226                                               2515
# 227                                               3065
# 228                                               1619
# 229                                               1499
#
#        Var. mensual (%)    Var. Anual (%)
# ...
